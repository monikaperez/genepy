# %%
import pandas as pd
import numpy as np
import dalmatian as dm
import pdb
import TerraFunction as terra
# %load_ext autoreload
# %autoreload 2

# %%
dm.__version__
# Out:
# '0.0.10'

# %% [markdown]
# ## initializing data

# %%
maleintervals = "gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642da12f8/immediate/intervalsXY.list"
femaleintervals = "gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642da12f8/immediate/intervalsXX.list"
sample_values_todrop = ["sj_diseases","sj_datasets","attr_age_at_diagnosis","attr_sex","attr_race","attr_ethnicity","attr_diagnosis"]
outpath = "sample.tsv"
spamplepath = "SAMPLE_INFO.txt"
bucketname= "gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642da12f8/"
samplesetname = "WGS_CNV_stjude"
namespace="rmc-rnaseq"
workspace="St_Jude_RMS"

# %% [markdown]
# ## uploading the required interval list of chromosomes for the PON

# %%
! echo "chr1\nchr2\nchr3\nchr4\nchr5\nchr6\nchr7\nchr8\nchr9\nchr10\nchr11\nchr12\nchr13\nchr14\nchr15\nchr16\nchr17\nchr18\nchr19\nchr20\nchr21\nchr22\nchrX\nchrY" > intervalsXY.list
! echo "chr1\nchr2\nchr3\nchr4\nchr5\nchr6\nchr7\nchr8\nchr9\nchr10\nchr11\nchr12\nchr13\nchr14\nchr15\nchr16\nchr17\nchr18\nchr19\nchr20\nchr21\nchr22\nchrX\nchrX" > intervalsXX.list
! gsutil cp intervalsXY.list $maleintervals
! gsutil cp intervalsXX.list $femaleintervals
# Out:
# Copying file://intervalsXY.list [Content-Type=text/plain]...
# / [1 files][  133.0 B/  133.0 B]
# Operation completed over 1 objects/133.0 B.
# Copying file://intervalsXX.list [Content-Type=text/plain]...
# / [1 files][  133.0 B/  133.0 B]
# Operation completed over 1 objects/133.0 B.

# %% [markdown]
# ## loading and Displaying data

# %%
newsample = pd.read_csv(spamplepath,sep='\t')
newsample
# Out:
#                                              file_path subject_name  \
# 0        /immediate/bam/SJRHB002_G.WholeGenome.bam.bai     SJRHB002
# 1            /immediate/bam/SJRHB002_G.WholeGenome.bam     SJRHB002
# 2            /immediate/bam/SJRHB005_G.WholeGenome.bam     SJRHB005
# 3        /immediate/bam/SJRHB005_G.WholeGenome.bam.bai     SJRHB005
# 4            /immediate/bam/SJRHB001_D.WholeGenome.bam     SJRHB001
# 5        /immediate/bam/SJRHB001_D.WholeGenome.bam.bai     SJRHB001
# 6            /immediate/bam/SJRHB001_G.WholeGenome.bam     SJRHB001
# 7        /immediate/bam/SJRHB001_G.WholeGenome.bam.bai     SJRHB001
# 8        /immediate/bam/SJRHB003_D.WholeGenome.bam.bai     SJRHB003
# 9            /immediate/bam/SJRHB003_D.WholeGenome.bam     SJRHB003
# 10           /immediate/bam/SJRHB004_D.WholeGenome.bam     SJRHB004
# 11           /immediate/bam/SJRHB002_D.WholeGenome.bam     SJRHB002
# 12       /immediate/bam/SJRHB004_D.WholeGenome.bam.bai     SJRHB004
# 13       /immediate/bam/SJRHB002_D.WholeGenome.bam.bai     SJRHB002
# 14       /immediate/bam/SJRHB000026_R4.WholeGenome.bam  SJRHB000026
# 15   /immediate/bam/SJRHB000026_R4.WholeGenome.bam.bai  SJRHB000026
# 16           /immediate/bam/SJRHB005_D.WholeGenome.bam     SJRHB005
# 17       /immediate/bam/SJRHB005_D.WholeGenome.bam.bai     SJRHB005
# 18   /immediate/bam/SJRHB000026_R5.WholeGenome.bam.bai  SJRHB000026
# 19       /immediate/bam/SJRHB000026_R5.WholeGenome.bam  SJRHB000026
# 20       /immediate/bam/SJRHB000026_R3.WholeGenome.bam  SJRHB000026
# 21   /immediate/bam/SJRHB000026_R3.WholeGenome.bam.bai  SJRHB000026
# 22           /immediate/bam/SJRHB012_S.WholeGenome.bam     SJRHB012
# 23       /immediate/bam/SJRHB012_S.WholeGenome.bam.bai     SJRHB012
# 24           /immediate/bam/SJRHB012_R.WholeGenome.bam     SJRHB012
# 25       /immediate/bam/SJRHB012_R.WholeGenome.bam.bai     SJRHB012
# 26           /immediate/bam/SJRHB011_G.WholeGenome.bam     SJRHB011
# 27       /immediate/bam/SJRHB011_G.WholeGenome.bam.bai     SJRHB011
# 28           /immediate/bam/SJRHB009_G.WholeGenome.bam     SJRHB009
# 29       /immediate/bam/SJRHB009_G.WholeGenome.bam.bai     SJRHB009
# ..                                                 ...          ...
# 686          /immediate/bam/SJRHB020_A.RNA-Seq.bam.bai     SJRHB020
# 687          /immediate/bam/SJRHB008_D.RNA-Seq.bam.bai     SJRHB008
# 688          /immediate/bam/SJRHB005_D.RNA-Seq.bam.bai     SJRHB005
# 689          /immediate/bam/SJRHB022_D.RNA-Seq.bam.bai     SJRHB022
# 690          /immediate/bam/SJRHB009_D.RNA-Seq.bam.bai     SJRHB009
# 691          /immediate/bam/SJRHB026_X.RNA-Seq.bam.bai     SJRHB026
# 692          /immediate/bam/SJRHB026_R.RNA-Seq.bam.bai     SJRHB026
# 693          /immediate/bam/SJRHB027_D.RNA-Seq.bam.bai     SJRHB027
# 694          /immediate/bam/SJRHB012_X.RNA-Seq.bam.bai     SJRHB012
# 695          /immediate/bam/SJRHB023_D.RNA-Seq.bam.bai     SJRHB023
# 696          /immediate/bam/SJRHB016_D.RNA-Seq.bam.bai     SJRHB016
# 697          /immediate/bam/SJRHB026_D.RNA-Seq.bam.bai     SJRHB026
# 698          /immediate/bam/SJRHB033_D.RNA-Seq.bam.bai     SJRHB033
# 699          /immediate/bam/SJRHB031_D.RNA-Seq.bam.bai     SJRHB031
# 700          /immediate/bam/SJRHB028_D.RNA-Seq.bam.bai     SJRHB028
# 701          /immediate/bam/SJRHB026_S.RNA-Seq.bam.bai     SJRHB026
# 702          /immediate/bam/SJRHB035_R.RNA-Seq.bam.bai     SJRHB035
# 703          /immediate/bam/SJRHB036_A.RNA-Seq.bam.bai     SJRHB036
# 704          /immediate/bam/SJRHB034_D.RNA-Seq.bam.bai     SJRHB034
# 705          /immediate/bam/SJRHB039_D.RNA-Seq.bam.bai     SJRHB039
# 706          /immediate/bam/SJRHB038_R.RNA-Seq.bam.bai     SJRHB038
# 707          /immediate/bam/SJRHB047_D.RNA-Seq.bam.bai     SJRHB047
# 708          /immediate/bam/SJRHB045_D.RNA-Seq.bam.bai     SJRHB045
# 709          /immediate/bam/SJRHB048_D.RNA-Seq.bam.bai     SJRHB048
# 710          /immediate/bam/SJRHB056_D.RNA-Seq.bam.bai     SJRHB056
# 711          /immediate/bam/SJRHB057_R.RNA-Seq.bam.bai     SJRHB057
# 712          /immediate/bam/SJRHB043_R.RNA-Seq.bam.bai     SJRHB043
# 713          /immediate/bam/SJRHB050_D.RNA-Seq.bam.bai     SJRHB050
# 714          /immediate/bam/SJRHB044_M.RNA-Seq.bam.bai     SJRHB044
# 715          /immediate/bam/SJRHB054_R.RNA-Seq.bam.bai     SJRHB054
#
#         sample_name sample_type sequencing_type file_type  description  \
# 0        SJRHB002_G    Germline             WGS       bam          NaN
# 1        SJRHB002_G    Germline             WGS       bam          NaN
# 2        SJRHB005_G    Germline             WGS       bam          NaN
# 3        SJRHB005_G    Germline             WGS       bam          NaN
# 4        SJRHB001_D   Diagnosis             WGS       bam          NaN
# 5        SJRHB001_D   Diagnosis             WGS       bam          NaN
# 6        SJRHB001_G    Germline             WGS       bam          NaN
# 7        SJRHB001_G    Germline             WGS       bam          NaN
# 8        SJRHB003_D   Diagnosis             WGS       bam          NaN
# 9        SJRHB003_D   Diagnosis             WGS       bam          NaN
# 10       SJRHB004_D   Diagnosis             WGS       bam          NaN
# 11       SJRHB002_D   Diagnosis             WGS       bam          NaN
# 12       SJRHB004_D   Diagnosis             WGS       bam          NaN
# 13       SJRHB002_D   Diagnosis             WGS       bam          NaN
# 14   SJRHB000026_R4     Relapse             WGS       bam          NaN
# 15   SJRHB000026_R4     Relapse             WGS       bam          NaN
# 16       SJRHB005_D   Diagnosis             WGS       bam          NaN
# 17       SJRHB005_D   Diagnosis             WGS       bam          NaN
# 18   SJRHB000026_R5     Relapse             WGS       bam          NaN
# 19   SJRHB000026_R5     Relapse             WGS       bam          NaN
# 20   SJRHB000026_R3     Relapse             WGS       bam          NaN
# 21   SJRHB000026_R3     Relapse             WGS       bam          NaN
# 22       SJRHB012_S     Relapse             WGS       bam          NaN
# 23       SJRHB012_S     Relapse             WGS       bam          NaN
# 24       SJRHB012_R     Relapse             WGS       bam          NaN
# 25       SJRHB012_R     Relapse             WGS       bam          NaN
# 26       SJRHB011_G    Germline             WGS       bam          NaN
# 27       SJRHB011_G    Germline             WGS       bam          NaN
# 28       SJRHB009_G    Germline             WGS       bam          NaN
# 29       SJRHB009_G    Germline             WGS       bam          NaN
# ..              ...         ...             ...       ...          ...
# 686      SJRHB020_A     Autopsy         RNA-Seq       bam          NaN
# 687      SJRHB008_D   Diagnosis         RNA-Seq       bam          NaN
# 688      SJRHB005_D   Diagnosis         RNA-Seq       bam          NaN
# 689      SJRHB022_D   Diagnosis         RNA-Seq       bam          NaN
# 690      SJRHB009_D   Diagnosis         RNA-Seq       bam          NaN
# 691      SJRHB026_X   Xenograft         RNA-Seq       bam          NaN
# 692      SJRHB026_R     Relapse         RNA-Seq       bam          NaN
# 693      SJRHB027_D   Diagnosis         RNA-Seq       bam          NaN
# 694      SJRHB012_X   Xenograft         RNA-Seq       bam          NaN
# 695      SJRHB023_D   Diagnosis         RNA-Seq       bam          NaN
# 696      SJRHB016_D   Diagnosis         RNA-Seq       bam          NaN
# 697      SJRHB026_D   Diagnosis         RNA-Seq       bam          NaN
# 698      SJRHB033_D   Diagnosis         RNA-Seq       bam          NaN
# 699      SJRHB031_D   Diagnosis         RNA-Seq       bam          NaN
# 700      SJRHB028_D   Diagnosis         RNA-Seq       bam          NaN
# 701      SJRHB026_S     Relapse         RNA-Seq       bam          NaN
# 702      SJRHB035_R     Relapse         RNA-Seq       bam          NaN
# 703      SJRHB036_A     Autopsy         RNA-Seq       bam          NaN
# 704      SJRHB034_D   Diagnosis         RNA-Seq       bam          NaN
# 705      SJRHB039_D   Diagnosis         RNA-Seq       bam          NaN
# 706      SJRHB038_R     Relapse         RNA-Seq       bam          NaN
# 707      SJRHB047_D   Diagnosis         RNA-Seq       bam          NaN
# 708      SJRHB045_D   Diagnosis         RNA-Seq       bam          NaN
# 709      SJRHB048_D   Diagnosis         RNA-Seq       bam          NaN
# 710      SJRHB056_D   Diagnosis         RNA-Seq       bam          NaN
# 711      SJRHB057_R     Relapse         RNA-Seq       bam          NaN
# 712      SJRHB043_R     Relapse         RNA-Seq       bam          NaN
# 713      SJRHB050_D   Diagnosis         RNA-Seq       bam          NaN
# 714      SJRHB044_M  Metastasis         RNA-Seq       bam          NaN
# 715      SJRHB054_R     Relapse         RNA-Seq       bam          NaN
#
#     sj_diseases                             sj_datasets  \
# 0           RHB  Pediatric Cancer Genome Project (PCGP)
# 1           RHB  Pediatric Cancer Genome Project (PCGP)
# 2           RHB  Pediatric Cancer Genome Project (PCGP)
# 3           RHB  Pediatric Cancer Genome Project (PCGP)
# 4           RHB  Pediatric Cancer Genome Project (PCGP)
# 5           RHB  Pediatric Cancer Genome Project (PCGP)
# 6           RHB  Pediatric Cancer Genome Project (PCGP)
# 7           RHB  Pediatric Cancer Genome Project (PCGP)
# 8           RHB  Pediatric Cancer Genome Project (PCGP)
# 9           RHB  Pediatric Cancer Genome Project (PCGP)
# 10          RHB  Pediatric Cancer Genome Project (PCGP)
# 11          RHB  Pediatric Cancer Genome Project (PCGP)
# 12          RHB  Pediatric Cancer Genome Project (PCGP)
# 13          RHB  Pediatric Cancer Genome Project (PCGP)
# 14          RHB  Pediatric Cancer Genome Project (PCGP)
# 15          RHB  Pediatric Cancer Genome Project (PCGP)
# 16          RHB  Pediatric Cancer Genome Project (PCGP)
# 17          RHB  Pediatric Cancer Genome Project (PCGP)
# 18          RHB  Pediatric Cancer Genome Project (PCGP)
# 19          RHB  Pediatric Cancer Genome Project (PCGP)
# 20          RHB  Pediatric Cancer Genome Project (PCGP)
# 21          RHB  Pediatric Cancer Genome Project (PCGP)
# 22          RHB  Pediatric Cancer Genome Project (PCGP)
# 23          RHB  Pediatric Cancer Genome Project (PCGP)
# 24          RHB  Pediatric Cancer Genome Project (PCGP)
# 25          RHB  Pediatric Cancer Genome Project (PCGP)
# 26          RHB  Pediatric Cancer Genome Project (PCGP)
# 27          RHB  Pediatric Cancer Genome Project (PCGP)
# 28          RHB  Pediatric Cancer Genome Project (PCGP)
# 29          RHB  Pediatric Cancer Genome Project (PCGP)
# ..          ...                                     ...
# 686         RHB  Pediatric Cancer Genome Project (PCGP)
# 687         RHB  Pediatric Cancer Genome Project (PCGP)
# 688         RHB  Pediatric Cancer Genome Project (PCGP)
# 689         RHB  Pediatric Cancer Genome Project (PCGP)
# 690         RHB  Pediatric Cancer Genome Project (PCGP)
# 691         RHB  Pediatric Cancer Genome Project (PCGP)
# 692         RHB  Pediatric Cancer Genome Project (PCGP)
# 693         RHB  Pediatric Cancer Genome Project (PCGP)
# 694         RHB  Pediatric Cancer Genome Project (PCGP)
# 695         RHB  Pediatric Cancer Genome Project (PCGP)
# 696         RHB  Pediatric Cancer Genome Project (PCGP)
# 697         RHB  Pediatric Cancer Genome Project (PCGP)
# 698         RHB  Pediatric Cancer Genome Project (PCGP)
# 699         RHB  Pediatric Cancer Genome Project (PCGP)
# 700         RHB  Pediatric Cancer Genome Project (PCGP)
# 701         RHB  Pediatric Cancer Genome Project (PCGP)
# 702         RHB  Pediatric Cancer Genome Project (PCGP)
# 703         RHB  Pediatric Cancer Genome Project (PCGP)
# 704         RHB  Pediatric Cancer Genome Project (PCGP)
# 705         RHB  Pediatric Cancer Genome Project (PCGP)
# 706         RHB  Pediatric Cancer Genome Project (PCGP)
# 707         RHB  Pediatric Cancer Genome Project (PCGP)
# 708         RHB  Pediatric Cancer Genome Project (PCGP)
# 709         RHB  Pediatric Cancer Genome Project (PCGP)
# 710         RHB  Pediatric Cancer Genome Project (PCGP)
# 711         RHB  Pediatric Cancer Genome Project (PCGP)
# 712         RHB  Pediatric Cancer Genome Project (PCGP)
# 713         RHB  Pediatric Cancer Genome Project (PCGP)
# 714         RHB  Pediatric Cancer Genome Project (PCGP)
# 715         RHB  Pediatric Cancer Genome Project (PCGP)
#
#              sj_pmid_accessions sj_ega_accessions  attr_age_at_diagnosis  \
# 0             23232254,24332040   EGAS00001000256               2.530000
# 1             23232254,24332040   EGAS00001000256               2.530000
# 2             23232254,24332040   EGAS00001000256               9.240000
# 3             23232254,24332040   EGAS00001000256               9.240000
# 4    23232254,24332040,28854978   EGAS00001000256               4.410000
# 5    23232254,24332040,28854978   EGAS00001000256               4.410000
# 6             23232254,24332040   EGAS00001000256               4.410000
# 7             23232254,24332040   EGAS00001000256               4.410000
# 8    23232254,24332040,28854978   EGAS00001000256               3.470000
# 9    23232254,24332040,28854978   EGAS00001000256               3.470000
# 10   23232254,24332040,28854978   EGAS00001000256               9.310000
# 11   23232254,24332040,28854978   EGAS00001000256               2.530000
# 12   23232254,24332040,28854978   EGAS00001000256               9.310000
# 13   23232254,24332040,28854978   EGAS00001000256               2.530000
# 14                          NaN               NaN                    NaN
# 15                          NaN               NaN                    NaN
# 16   23232254,24332040,28854978   EGAS00001000256               9.240000
# 17   23232254,24332040,28854978   EGAS00001000256               9.240000
# 18                          NaN               NaN                    NaN
# 19                          NaN               NaN                    NaN
# 20                          NaN               NaN                    NaN
# 21                          NaN               NaN                    NaN
# 22                     24332040   EGAS00001000256              17.310000
# 23                     24332040   EGAS00001000256              17.310000
# 24            24332040,28854978   EGAS00001000256              17.310000
# 25            24332040,28854978   EGAS00001000256              17.310000
# 26            23232254,24332040   EGAS00001000256               4.590000
# 27            23232254,24332040   EGAS00001000256               4.590000
# 28            23232254,24332040   EGAS00001000256               7.900000
# 29            23232254,24332040   EGAS00001000256               7.900000
# ..                          ...               ...                    ...
# 686                         NaN               NaN               1.166667
# 687                         NaN               NaN              16.700000
# 688                         NaN               NaN               9.240000
# 689                         NaN               NaN              14.416667
# 690                         NaN               NaN               7.900000
# 691                         NaN               NaN               0.710000
# 692                         NaN               NaN               0.710000
# 693                         NaN               NaN               1.890000
# 694                         NaN               NaN              17.310000
# 695                         NaN               NaN               2.583333
# 696                         NaN               NaN                    NaN
# 697                         NaN               NaN               0.710000
# 698                         NaN               NaN              13.850000
# 699                         NaN               NaN               0.370000
# 700                         NaN               NaN              15.260000
# 701                         NaN               NaN               0.710000
# 702                         NaN               NaN               7.250000
# 703                         NaN               NaN              14.230000
# 704                         NaN               NaN               0.120000
# 705                         NaN               NaN               3.250000
# 706                         NaN               NaN                    NaN
# 707                         NaN               NaN               5.260000
# 708                         NaN               NaN               2.840000
# 709                         NaN               NaN               2.410000
# 710                         NaN               NaN              12.920000
# 711                         NaN               NaN               4.250000
# 712                         NaN               NaN               1.920000
# 713                         NaN               NaN               7.760000
# 714                         NaN               NaN               6.150000
# 715                         NaN               NaN              16.666667
#
#             attr_diagnosis          attr_ethnicity                  attr_race  \
# 0     NOS,Rhabdomyosarcoma  Not Hispanic or Latino                      White
# 1     NOS,Rhabdomyosarcoma  Not Hispanic or Latino                      White
# 2     NOS,Rhabdomyosarcoma  Not Hispanic or Latino  Black or African American
# 3     NOS,Rhabdomyosarcoma  Not Hispanic or Latino  Black or African American
# 4     NOS,Rhabdomyosarcoma  Not Hispanic or Latino  Black or African American
# 5     NOS,Rhabdomyosarcoma  Not Hispanic or Latino  Black or African American
# 6     NOS,Rhabdomyosarcoma  Not Hispanic or Latino  Black or African American
# 7     NOS,Rhabdomyosarcoma  Not Hispanic or Latino  Black or African American
# 8     NOS,Rhabdomyosarcoma  Not Hispanic or Latino  Black or African American
# 9     NOS,Rhabdomyosarcoma  Not Hispanic or Latino  Black or African American
# 10    NOS,Rhabdomyosarcoma  Not Hispanic or Latino                      White
# 11    NOS,Rhabdomyosarcoma  Not Hispanic or Latino                      White
# 12    NOS,Rhabdomyosarcoma  Not Hispanic or Latino                      White
# 13    NOS,Rhabdomyosarcoma  Not Hispanic or Latino                      White
# 14                     NaN                     NaN                        NaN
# 15                     NaN                     NaN                        NaN
# 16    NOS,Rhabdomyosarcoma  Not Hispanic or Latino  Black or African American
# 17    NOS,Rhabdomyosarcoma  Not Hispanic or Latino  Black or African American
# 18                     NaN                     NaN                        NaN
# 19                     NaN                     NaN                        NaN
# 20                     NaN                     NaN                        NaN
# 21                     NaN                     NaN                        NaN
# 22    NOS,Rhabdomyosarcoma  Not Hispanic or Latino                      White
# 23    NOS,Rhabdomyosarcoma  Not Hispanic or Latino                      White
# 24    NOS,Rhabdomyosarcoma  Not Hispanic or Latino                      White
# 25    NOS,Rhabdomyosarcoma  Not Hispanic or Latino                      White
# 26    NOS,Rhabdomyosarcoma  Not Hispanic or Latino                      White
# 27    NOS,Rhabdomyosarcoma  Not Hispanic or Latino                      White
# 28    NOS,Rhabdomyosarcoma  Not Hispanic or Latino  Black or African American
# 29    NOS,Rhabdomyosarcoma  Not Hispanic or Latino  Black or African American
# ..                     ...                     ...                        ...
# 686  Rhabdomyosarcoma, NOS                     NaN                      White
# 687  Rhabdomyosarcoma, NOS  Not Hispanic or Latino                      White
# 688  Rhabdomyosarcoma, NOS  Not Hispanic or Latino  Black or African American
# 689  Rhabdomyosarcoma, NOS                     NaN                      White
# 690  Rhabdomyosarcoma, NOS  Not Hispanic or Latino  Black or African American
# 691  Rhabdomyosarcoma, NOS  Not Hispanic or Latino                      White
# 692  Rhabdomyosarcoma, NOS  Not Hispanic or Latino                      White
# 693  Rhabdomyosarcoma, NOS  Not Hispanic or Latino  Black or African American
# 694  Rhabdomyosarcoma, NOS  Not Hispanic or Latino                      White
# 695  Rhabdomyosarcoma, NOS                     NaN                      White
# 696                    NaN                     NaN                        NaN
# 697  Rhabdomyosarcoma, NOS  Not Hispanic or Latino                      White
# 698  Rhabdomyosarcoma, NOS  Not Hispanic or Latino  Black or African American
# 699  Rhabdomyosarcoma, NOS  Not Hispanic or Latino                      White
# 700  Rhabdomyosarcoma, NOS  Not Hispanic or Latino                      White
# 701  Rhabdomyosarcoma, NOS  Not Hispanic or Latino                      White
# 702  Rhabdomyosarcoma, NOS                     NaN                      White
# 703  Rhabdomyosarcoma, NOS  Not Hispanic or Latino                      White
# 704  Rhabdomyosarcoma, NOS  Not Hispanic or Latino                      White
# 705  Rhabdomyosarcoma, NOS  Not Hispanic or Latino                      White
# 706                    NaN                     NaN                        NaN
# 707  Rhabdomyosarcoma, NOS  Not Hispanic or Latino                      White
# 708  Rhabdomyosarcoma, NOS  Not Hispanic or Latino  Black or African American
# 709  Rhabdomyosarcoma, NOS  Not Hispanic or Latino                      White
# 710  Rhabdomyosarcoma, NOS  Not Hispanic or Latino                      White
# 711  Rhabdomyosarcoma, NOS                     NaN                      White
# 712  Rhabdomyosarcoma, NOS  Not Hispanic or Latino                      White
# 713  Rhabdomyosarcoma, NOS  Not Hispanic or Latino                      White
# 714  Rhabdomyosarcoma, NOS                     NaN                      White
# 715  Rhabdomyosarcoma, NOS                     NaN                      White
#
#     attr_sex sj_dataset_accessions sj_embargo_date sj_genome_build
# 0     Female           SJC-DS-1001     2018,Jul 23             NaN
# 1     Female           SJC-DS-1001     2018,Jul 23             NaN
# 2     Female           SJC-DS-1001     2018,Jul 23             NaN
# 3     Female           SJC-DS-1001     2018,Jul 23             NaN
# 4       Male           SJC-DS-1001     2018,Jul 23             NaN
# 5       Male           SJC-DS-1001     2018,Jul 23             NaN
# 6       Male           SJC-DS-1001     2018,Jul 23             NaN
# 7       Male           SJC-DS-1001     2018,Jul 23             NaN
# 8     Female           SJC-DS-1001     2018,Jul 23             NaN
# 9     Female           SJC-DS-1001     2018,Jul 23             NaN
# 10      Male           SJC-DS-1001     2018,Jul 23             NaN
# 11    Female           SJC-DS-1001     2018,Jul 23             NaN
# 12      Male           SJC-DS-1001     2018,Jul 23             NaN
# 13    Female           SJC-DS-1001     2018,Jul 23             NaN
# 14       NaN           SJC-DS-1001     2018,Jul 23             NaN
# 15       NaN           SJC-DS-1001     2018,Jul 23             NaN
# 16    Female           SJC-DS-1001     2018,Jul 23             NaN
# 17    Female           SJC-DS-1001     2018,Jul 23             NaN
# 18       NaN           SJC-DS-1001     2018,Jul 23             NaN
# 19       NaN           SJC-DS-1001     2018,Jul 23             NaN
# 20       NaN           SJC-DS-1001     2018,Jul 23             NaN
# 21       NaN           SJC-DS-1001     2018,Jul 23             NaN
# 22      Male           SJC-DS-1001     2018,Jul 23             NaN
# 23      Male           SJC-DS-1001     2018,Jul 23             NaN
# 24      Male           SJC-DS-1001     2018,Jul 23             NaN
# 25      Male           SJC-DS-1001     2018,Jul 23             NaN
# 26      Male           SJC-DS-1001     2018,Jul 23             NaN
# 27      Male           SJC-DS-1001     2018,Jul 23             NaN
# 28    Female           SJC-DS-1001     2018,Jul 23             NaN
# 29    Female           SJC-DS-1001     2018,Jul 23             NaN
# ..       ...                   ...             ...             ...
# 686   Female           SJC-DS-1001       23-Jul-18             NaN
# 687   Female           SJC-DS-1001       23-Jul-18             NaN
# 688   Female           SJC-DS-1001       23-Jul-18             NaN
# 689     Male           SJC-DS-1001       23-Jul-18             NaN
# 690   Female           SJC-DS-1001       23-Jul-18             NaN
# 691   Female           SJC-DS-1001       23-Jul-18             NaN
# 692   Female           SJC-DS-1001       23-Jul-18             NaN
# 693   Female           SJC-DS-1001       23-Jul-18             NaN
# 694     Male           SJC-DS-1001       23-Jul-18             NaN
# 695     Male           SJC-DS-1001       23-Jul-18             NaN
# 696      NaN           SJC-DS-1001       23-Jul-18             NaN
# 697   Female           SJC-DS-1001       23-Jul-18             NaN
# 698     Male           SJC-DS-1001       23-Jul-18             NaN
# 699   Female           SJC-DS-1001       23-Jul-18             NaN
# 700     Male           SJC-DS-1001       23-Jul-18             NaN
# 701   Female           SJC-DS-1001       23-Jul-18             NaN
# 702   Female           SJC-DS-1001       23-Jul-18             NaN
# 703   Female           SJC-DS-1001       23-Jul-18             NaN
# 704   Female           SJC-DS-1001       23-Jul-18             NaN
# 705     Male           SJC-DS-1001       23-Jul-18             NaN
# 706      NaN           SJC-DS-1001       23-Jul-18             NaN
# 707   Female           SJC-DS-1001       23-Jul-18             NaN
# 708     Male           SJC-DS-1001       23-Jul-18             NaN
# 709     Male           SJC-DS-1001       23-Jul-18             NaN
# 710     Male           SJC-DS-1001       23-Jul-18             NaN
# 711     Male           SJC-DS-1001       23-Jul-18             NaN
# 712     Male           SJC-DS-1001       23-Jul-18             NaN
# 713     Male           SJC-DS-1001       23-Jul-18             NaN
# 714   Female           SJC-DS-1001       23-Jul-18             NaN
# 715   Female           SJC-DS-1001       23-Jul-18             NaN
#
# [716 rows x 19 columns]

# %%
#only keeping whole genome
for i,val in enumerate(newsample["file_path"]):
    if val.split('/')[-1].split('.')[1] != "WholeGenome" or val.split('/')[-2]!= "bam":
        newsample = newsample.drop(i)
    elif val.split('/')[1] != 'gs:':
        newsample["file_path"][i]="gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642da12f8/immediate/bam_wg/"+newsample["file_path"][i].split('/')[-1]
newsample = newsample.reset_index(drop=True)
newsample = newsample.rename(index=str, columns={"sample_name": "sample_id", "subject_name": "participant_id","file_path":"WGS_bam"})
currfile=""
bai = ['']*int(newsample.shape[0])
#creating an array of bai and adding it to their coresponding bams
for i in newsample.index:
    currfile=newsample["WGS_bam"][i]
    if currfile.split('/')[-1].split('.')[-1] == "bai":
        bai[int(newsample[newsample["WGS_bam"]==currfile[:-4]].index.values[0])] = currfile
newsample["WGS_bam_index"]=pd.Series(bai,index=newsample.index)
#removing original bai rows
for i in newsample.index: 
    currfile=newsample["WGS_bam"][i]
    if currfile.split('/')[-1].split('.')[-1] == "bai":
        newsample = newsample.drop(i)
newsample = newsample.reset_index(drop=True)
newsample["sample_set"]=pd.Series([samplesetname]*int(newsample.shape[0]),index=newsample.index)
newsample.set_index("sample_id",inplace=True,drop=True)
newsample = newsample[newsample.columns.tolist()[1:]+[newsample.columns.tolist()[0]]]
newsample = newsample.loc[~newsample.index.duplicated(keep='first')]
newsample.to_csv(outpath,sep="\t")
newsample
# Out:
# /Users/jeremie/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                participant_id sample_type sequencing_type file_type  \
# sample_id
# SJRHB002_G           SJRHB002    Germline             WGS       bam
# SJRHB005_G           SJRHB005    Germline             WGS       bam
# SJRHB001_D           SJRHB001   Diagnosis             WGS       bam
# SJRHB001_G           SJRHB001    Germline             WGS       bam
# SJRHB003_D           SJRHB003   Diagnosis             WGS       bam
# SJRHB004_D           SJRHB004   Diagnosis             WGS       bam
# SJRHB002_D           SJRHB002   Diagnosis             WGS       bam
# SJRHB000026_R4    SJRHB000026     Relapse             WGS       bam
# SJRHB005_D           SJRHB005   Diagnosis             WGS       bam
# SJRHB000026_R5    SJRHB000026     Relapse             WGS       bam
# SJRHB000026_R3    SJRHB000026     Relapse             WGS       bam
# SJRHB012_S           SJRHB012     Relapse             WGS       bam
# SJRHB012_R           SJRHB012     Relapse             WGS       bam
# SJRHB011_G           SJRHB011    Germline             WGS       bam
# SJRHB009_G           SJRHB009    Germline             WGS       bam
# SJRHB012_G           SJRHB012    Germline             WGS       bam
# SJRHB013_G           SJRHB013    Germline             WGS       bam
# SJRHB011_D           SJRHB011   Diagnosis             WGS       bam
# SJRHB009_D           SJRHB009   Diagnosis             WGS       bam
# SJRHB010_G           SJRHB010    Germline             WGS       bam
# SJRHB003_G           SJRHB003    Germline             WGS       bam
# SJRHB010_D           SJRHB010   Diagnosis             WGS       bam
# SJRHB012_D           SJRHB012   Diagnosis             WGS       bam
# SJRHB004_G           SJRHB004    Germline             WGS       bam
# SJRHB007_G           SJRHB007    Germline             WGS       bam
# SJRHB008_G           SJRHB008    Germline             WGS       bam
# SJRHB011_E           SJRHB011   Diagnosis             WGS       bam
# SJRHB008_D           SJRHB008   Diagnosis             WGS       bam
# SJRHB006_G           SJRHB006    Germline             WGS       bam
# SJRHB006_D           SJRHB006   Diagnosis             WGS       bam
# SJRHB007_D           SJRHB007   Diagnosis             WGS       bam
# SJRHB013_D           SJRHB013   Diagnosis             WGS       bam
# SJRHB030348_G1    SJRHB030348    Germline             WGS       bam
# SJRHB030264_G1    SJRHB030264    Germline             WGS       bam
# SJRHB030264_D1    SJRHB030264   Diagnosis             WGS       bam
# SJRHB030115_D1    SJRHB030115   Diagnosis             WGS       bam
# SJRHB030142_D1    SJRHB030142   Diagnosis             WGS       bam
# SJRHB030115_G1    SJRHB030115    Germline             WGS       bam
# SJRHB013_H           SJRHB013    Germline             WGS       bam
# SJRHB010_H           SJRHB010    Germline             WGS       bam
#
#                 description sj_diseases  \
# sample_id
# SJRHB002_G              NaN         RHB
# SJRHB005_G              NaN         RHB
# SJRHB001_D              NaN         RHB
# SJRHB001_G              NaN         RHB
# SJRHB003_D              NaN         RHB
# SJRHB004_D              NaN         RHB
# SJRHB002_D              NaN         RHB
# SJRHB000026_R4          NaN         RHB
# SJRHB005_D              NaN         RHB
# SJRHB000026_R5          NaN         RHB
# SJRHB000026_R3          NaN         RHB
# SJRHB012_S              NaN         RHB
# SJRHB012_R              NaN         RHB
# SJRHB011_G              NaN         RHB
# SJRHB009_G              NaN         RHB
# SJRHB012_G              NaN         RHB
# SJRHB013_G              NaN         RHB
# SJRHB011_D              NaN         RHB
# SJRHB009_D              NaN         RHB
# SJRHB010_G              NaN         RHB
# SJRHB003_G              NaN         RHB
# SJRHB010_D              NaN         RHB
# SJRHB012_D              NaN         RHB
# SJRHB004_G              NaN         RHB
# SJRHB007_G              NaN         RHB
# SJRHB008_G              NaN         RHB
# SJRHB011_E              NaN         RHB
# SJRHB008_D              NaN         RHB
# SJRHB006_G              NaN         RHB
# SJRHB006_D              NaN         RHB
# SJRHB007_D              NaN         RHB
# SJRHB013_D              NaN         RHB
# SJRHB030348_G1          NaN         RHB
# SJRHB030264_G1          NaN         RHB
# SJRHB030264_D1          NaN         RHB
# SJRHB030115_D1          NaN         RHB
# SJRHB030142_D1          NaN         RHB
# SJRHB030115_G1          NaN         RHB
# SJRHB013_H              NaN         RHB
# SJRHB010_H              NaN         RHB
#
#                                            sj_datasets  \
# sample_id
# SJRHB002_G      Pediatric Cancer Genome Project (PCGP)
# SJRHB005_G      Pediatric Cancer Genome Project (PCGP)
# SJRHB001_D      Pediatric Cancer Genome Project (PCGP)
# SJRHB001_G      Pediatric Cancer Genome Project (PCGP)
# SJRHB003_D      Pediatric Cancer Genome Project (PCGP)
# SJRHB004_D      Pediatric Cancer Genome Project (PCGP)
# SJRHB002_D      Pediatric Cancer Genome Project (PCGP)
# SJRHB000026_R4  Pediatric Cancer Genome Project (PCGP)
# SJRHB005_D      Pediatric Cancer Genome Project (PCGP)
# SJRHB000026_R5  Pediatric Cancer Genome Project (PCGP)
# SJRHB000026_R3  Pediatric Cancer Genome Project (PCGP)
# SJRHB012_S      Pediatric Cancer Genome Project (PCGP)
# SJRHB012_R      Pediatric Cancer Genome Project (PCGP)
# SJRHB011_G      Pediatric Cancer Genome Project (PCGP)
# SJRHB009_G      Pediatric Cancer Genome Project (PCGP)
# SJRHB012_G      Pediatric Cancer Genome Project (PCGP)
# SJRHB013_G      Pediatric Cancer Genome Project (PCGP)
# SJRHB011_D      Pediatric Cancer Genome Project (PCGP)
# SJRHB009_D      Pediatric Cancer Genome Project (PCGP)
# SJRHB010_G      Pediatric Cancer Genome Project (PCGP)
# SJRHB003_G      Pediatric Cancer Genome Project (PCGP)
# SJRHB010_D      Pediatric Cancer Genome Project (PCGP)
# SJRHB012_D      Pediatric Cancer Genome Project (PCGP)
# SJRHB004_G      Pediatric Cancer Genome Project (PCGP)
# SJRHB007_G      Pediatric Cancer Genome Project (PCGP)
# SJRHB008_G      Pediatric Cancer Genome Project (PCGP)
# SJRHB011_E      Pediatric Cancer Genome Project (PCGP)
# SJRHB008_D      Pediatric Cancer Genome Project (PCGP)
# SJRHB006_G      Pediatric Cancer Genome Project (PCGP)
# SJRHB006_D      Pediatric Cancer Genome Project (PCGP)
# SJRHB007_D      Pediatric Cancer Genome Project (PCGP)
# SJRHB013_D      Pediatric Cancer Genome Project (PCGP)
# SJRHB030348_G1                    Genomes 4 Kids (G4K)
# SJRHB030264_G1                    Genomes 4 Kids (G4K)
# SJRHB030264_D1                    Genomes 4 Kids (G4K)
# SJRHB030115_D1                    Genomes 4 Kids (G4K)
# SJRHB030142_D1                    Genomes 4 Kids (G4K)
# SJRHB030115_G1                    Genomes 4 Kids (G4K)
# SJRHB013_H                              Clinical Pilot
# SJRHB010_H                              Clinical Pilot
#
#                         sj_pmid_accessions sj_ega_accessions  \
# sample_id
# SJRHB002_G               23232254,24332040   EGAS00001000256
# SJRHB005_G               23232254,24332040   EGAS00001000256
# SJRHB001_D      23232254,24332040,28854978   EGAS00001000256
# SJRHB001_G               23232254,24332040   EGAS00001000256
# SJRHB003_D      23232254,24332040,28854978   EGAS00001000256
# SJRHB004_D      23232254,24332040,28854978   EGAS00001000256
# SJRHB002_D      23232254,24332040,28854978   EGAS00001000256
# SJRHB000026_R4                         NaN               NaN
# SJRHB005_D      23232254,24332040,28854978   EGAS00001000256
# SJRHB000026_R5                         NaN               NaN
# SJRHB000026_R3                         NaN               NaN
# SJRHB012_S                        24332040   EGAS00001000256
# SJRHB012_R               24332040,28854978   EGAS00001000256
# SJRHB011_G               23232254,24332040   EGAS00001000256
# SJRHB009_G               23232254,24332040   EGAS00001000256
# SJRHB012_G               23232254,24332040   EGAS00001000256
# SJRHB013_G               23232254,24332040   EGAS00001000256
# SJRHB011_D               23232254,24332040   EGAS00001000256
# SJRHB009_D      23232254,24332040,28854978   EGAS00001000256
# SJRHB010_G               23232254,24332040   EGAS00001000256
# SJRHB003_G               23232254,24332040   EGAS00001000256
# SJRHB010_D      23232254,24332040,28854978   EGAS00001000256
# SJRHB012_D      23232254,24332040,28854978   EGAS00001000256
# SJRHB004_G               23232254,24332040   EGAS00001000256
# SJRHB007_G               23232254,24332040   EGAS00001000256
# SJRHB008_G               23232254,24332040   EGAS00001000256
# SJRHB011_E               24332040,28854978   EGAS00001000256
# SJRHB008_D      23232254,24332040,28854978   EGAS00001000256
# SJRHB006_G               23232254,24332040   EGAS00001000256
# SJRHB006_D      23232254,24332040,28854978   EGAS00001000256
# SJRHB007_D      23232254,24332040,28854978   EGAS00001000256
# SJRHB013_D      23232254,24332040,28854978               NaN
# SJRHB030348_G1                         NaN               NaN
# SJRHB030264_G1                         NaN               NaN
# SJRHB030264_D1                         NaN               NaN
# SJRHB030115_D1                         NaN               NaN
# SJRHB030142_D1                         NaN               NaN
# SJRHB030115_G1                         NaN               NaN
# SJRHB013_H                             NaN               NaN
# SJRHB010_H                             NaN               NaN
#
#                 attr_age_at_diagnosis        attr_diagnosis  \
# sample_id
# SJRHB002_G                   2.530000  NOS,Rhabdomyosarcoma
# SJRHB005_G                   9.240000  NOS,Rhabdomyosarcoma
# SJRHB001_D                   4.410000  NOS,Rhabdomyosarcoma
# SJRHB001_G                   4.410000  NOS,Rhabdomyosarcoma
# SJRHB003_D                   3.470000  NOS,Rhabdomyosarcoma
# SJRHB004_D                   9.310000  NOS,Rhabdomyosarcoma
# SJRHB002_D                   2.530000  NOS,Rhabdomyosarcoma
# SJRHB000026_R4                    NaN                   NaN
# SJRHB005_D                   9.240000  NOS,Rhabdomyosarcoma
# SJRHB000026_R5                    NaN                   NaN
# SJRHB000026_R3                    NaN                   NaN
# SJRHB012_S                  17.310000  NOS,Rhabdomyosarcoma
# SJRHB012_R                  17.310000  NOS,Rhabdomyosarcoma
# SJRHB011_G                   4.590000  NOS,Rhabdomyosarcoma
# SJRHB009_G                   7.900000  NOS,Rhabdomyosarcoma
# SJRHB012_G                  17.310000  NOS,Rhabdomyosarcoma
# SJRHB013_G                   1.370000  NOS,Rhabdomyosarcoma
# SJRHB011_D                   4.590000  NOS,Rhabdomyosarcoma
# SJRHB009_D                   7.900000  NOS,Rhabdomyosarcoma
# SJRHB010_G                   6.180000  NOS,Rhabdomyosarcoma
# SJRHB003_G                   3.470000  NOS,Rhabdomyosarcoma
# SJRHB010_D                   6.180000  NOS,Rhabdomyosarcoma
# SJRHB012_D                  17.310000  NOS,Rhabdomyosarcoma
# SJRHB004_G                   9.310000  NOS,Rhabdomyosarcoma
# SJRHB007_G                  16.916667  NOS,Rhabdomyosarcoma
# SJRHB008_G                  16.700000  NOS,Rhabdomyosarcoma
# SJRHB011_E                   4.590000  NOS,Rhabdomyosarcoma
# SJRHB008_D                  16.700000  NOS,Rhabdomyosarcoma
# SJRHB006_G                   7.840000  NOS,Rhabdomyosarcoma
# SJRHB006_D                   7.840000  NOS,Rhabdomyosarcoma
# SJRHB007_D                  16.916667  NOS,Rhabdomyosarcoma
# SJRHB013_D                   1.370000  NOS,Rhabdomyosarcoma
# SJRHB030348_G1               8.680000  NOS,Rhabdomyosarcoma
# SJRHB030264_G1              14.170000  NOS,Rhabdomyosarcoma
# SJRHB030264_D1              14.170000  NOS,Rhabdomyosarcoma
# SJRHB030115_D1               2.320000  NOS,Rhabdomyosarcoma
# SJRHB030142_D1               3.080000  NOS,Rhabdomyosarcoma
# SJRHB030115_G1               2.320000  NOS,Rhabdomyosarcoma
# SJRHB013_H                   1.370000  NOS,Rhabdomyosarcoma
# SJRHB010_H                   6.180000  NOS,Rhabdomyosarcoma
#
#                         attr_ethnicity                  attr_race attr_sex  \
# sample_id
# SJRHB002_G      Not Hispanic or Latino                      White   Female
# SJRHB005_G      Not Hispanic or Latino  Black or African American   Female
# SJRHB001_D      Not Hispanic or Latino  Black or African American     Male
# SJRHB001_G      Not Hispanic or Latino  Black or African American     Male
# SJRHB003_D      Not Hispanic or Latino  Black or African American   Female
# SJRHB004_D      Not Hispanic or Latino                      White     Male
# SJRHB002_D      Not Hispanic or Latino                      White   Female
# SJRHB000026_R4                     NaN                        NaN      NaN
# SJRHB005_D      Not Hispanic or Latino  Black or African American   Female
# SJRHB000026_R5                     NaN                        NaN      NaN
# SJRHB000026_R3                     NaN                        NaN      NaN
# SJRHB012_S      Not Hispanic or Latino                      White     Male
# SJRHB012_R      Not Hispanic or Latino                      White     Male
# SJRHB011_G      Not Hispanic or Latino                      White     Male
# SJRHB009_G      Not Hispanic or Latino  Black or African American   Female
# SJRHB012_G      Not Hispanic or Latino                      White     Male
# SJRHB013_G      Not Hispanic or Latino                      White   Female
# SJRHB011_D      Not Hispanic or Latino                      White     Male
# SJRHB009_D      Not Hispanic or Latino  Black or African American   Female
# SJRHB010_G      Not Hispanic or Latino                        NaN     Male
# SJRHB003_G      Not Hispanic or Latino  Black or African American   Female
# SJRHB010_D      Not Hispanic or Latino                        NaN     Male
# SJRHB012_D      Not Hispanic or Latino                      White     Male
# SJRHB004_G      Not Hispanic or Latino                      White     Male
# SJRHB007_G                         NaN                      White     Male
# SJRHB008_G      Not Hispanic or Latino                      White   Female
# SJRHB011_E      Not Hispanic or Latino                      White     Male
# SJRHB008_D      Not Hispanic or Latino                      White   Female
# SJRHB006_G      Not Hispanic or Latino                      White   Female
# SJRHB006_D      Not Hispanic or Latino                      White   Female
# SJRHB007_D                         NaN                      White     Male
# SJRHB013_D      Not Hispanic or Latino                      White   Female
# SJRHB030348_G1      Hispanic or Latino                      White     Male
# SJRHB030264_G1  Not Hispanic or Latino                      White   Female
# SJRHB030264_D1  Not Hispanic or Latino                      White   Female
# SJRHB030115_D1  Not Hispanic or Latino  Black or African American   Female
# SJRHB030142_D1  Not Hispanic or Latino                      White   Female
# SJRHB030115_G1  Not Hispanic or Latino  Black or African American   Female
# SJRHB013_H      Not Hispanic or Latino                      White   Female
# SJRHB010_H      Not Hispanic or Latino                        NaN     Male
#
#                sj_dataset_accessions sj_embargo_date sj_genome_build  \
# sample_id
# SJRHB002_G               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB005_G               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB001_D               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB001_G               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB003_D               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB004_D               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB002_D               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB000026_R4           SJC-DS-1001     2018,Jul 23             NaN
# SJRHB005_D               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB000026_R5           SJC-DS-1001     2018,Jul 23             NaN
# SJRHB000026_R3           SJC-DS-1001     2018,Jul 23             NaN
# SJRHB012_S               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB012_R               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB011_G               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB009_G               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB012_G               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB013_G               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB011_D               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB009_D               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB010_G               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB003_G               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB010_D               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB012_D               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB004_G               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB007_G               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB008_G               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB011_E               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB008_D               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB006_G               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB006_D               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB007_D               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB013_D               SJC-DS-1001     2018,Jul 23             NaN
# SJRHB030348_G1           SJC-DS-1004     2019,Jan 15             NaN
# SJRHB030264_G1           SJC-DS-1004     2019,Jan 15             NaN
# SJRHB030264_D1           SJC-DS-1004     2019,Jan 15             NaN
# SJRHB030115_D1           SJC-DS-1004     2019,Jan 15             NaN
# SJRHB030142_D1           SJC-DS-1004     2019,Jan 15             NaN
# SJRHB030115_G1           SJC-DS-1004     2019,Jan 15             NaN
# SJRHB013_H               SJC-DS-1003     2019,Jan 15             NaN
# SJRHB010_H               SJC-DS-1003     2019,Jan 15             NaN
#
#                                                     WGS_bam_index  \
# sample_id
# SJRHB002_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB005_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB001_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB001_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB003_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB004_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB002_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB000026_R4  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB005_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB000026_R5  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB000026_R3  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB012_S      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB012_R      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB011_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB009_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB012_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB013_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB011_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB009_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB010_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB003_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB010_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB012_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB004_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB007_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB008_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB011_E      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB008_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB006_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB006_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB007_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB013_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB030348_G1  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB030264_G1  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB030264_D1  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB030115_D1  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB030142_D1  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB030115_G1  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB013_H      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB010_H      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
#
#                     sample_set  \
# sample_id
# SJRHB002_G      WGS_CNV_stjude
# SJRHB005_G      WGS_CNV_stjude
# SJRHB001_D      WGS_CNV_stjude
# SJRHB001_G      WGS_CNV_stjude
# SJRHB003_D      WGS_CNV_stjude
# SJRHB004_D      WGS_CNV_stjude
# SJRHB002_D      WGS_CNV_stjude
# SJRHB000026_R4  WGS_CNV_stjude
# SJRHB005_D      WGS_CNV_stjude
# SJRHB000026_R5  WGS_CNV_stjude
# SJRHB000026_R3  WGS_CNV_stjude
# SJRHB012_S      WGS_CNV_stjude
# SJRHB012_R      WGS_CNV_stjude
# SJRHB011_G      WGS_CNV_stjude
# SJRHB009_G      WGS_CNV_stjude
# SJRHB012_G      WGS_CNV_stjude
# SJRHB013_G      WGS_CNV_stjude
# SJRHB011_D      WGS_CNV_stjude
# SJRHB009_D      WGS_CNV_stjude
# SJRHB010_G      WGS_CNV_stjude
# SJRHB003_G      WGS_CNV_stjude
# SJRHB010_D      WGS_CNV_stjude
# SJRHB012_D      WGS_CNV_stjude
# SJRHB004_G      WGS_CNV_stjude
# SJRHB007_G      WGS_CNV_stjude
# SJRHB008_G      WGS_CNV_stjude
# SJRHB011_E      WGS_CNV_stjude
# SJRHB008_D      WGS_CNV_stjude
# SJRHB006_G      WGS_CNV_stjude
# SJRHB006_D      WGS_CNV_stjude
# SJRHB007_D      WGS_CNV_stjude
# SJRHB013_D      WGS_CNV_stjude
# SJRHB030348_G1  WGS_CNV_stjude
# SJRHB030264_G1  WGS_CNV_stjude
# SJRHB030264_D1  WGS_CNV_stjude
# SJRHB030115_D1  WGS_CNV_stjude
# SJRHB030142_D1  WGS_CNV_stjude
# SJRHB030115_G1  WGS_CNV_stjude
# SJRHB013_H      WGS_CNV_stjude
# SJRHB010_H      WGS_CNV_stjude
#
#                                                           WGS_bam
# sample_id
# SJRHB002_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB005_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB001_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB001_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB003_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB004_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB002_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB000026_R4  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB005_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB000026_R5  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB000026_R3  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB012_S      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB012_R      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB011_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB009_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB012_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB013_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB011_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB009_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB010_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB003_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB010_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB012_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB004_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB007_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB008_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB011_E      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB008_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB006_G      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB006_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB007_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB013_D      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB030348_G1  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB030264_G1  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB030264_D1  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB030115_D1  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB030142_D1  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB030115_G1  gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB013_H      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...
# SJRHB010_H      gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642d...

# %% [markdown]
# Removing a corrupted sample

# %%
newsample=newsample.drop("SJRHB007_G")
newsample=newsample.drop("SJRHB010_D")

# %% [markdown]
# ## creating set for each samples

# %%
wm = dm.WorkspaceManager(namespace, workspace)

# %% [markdown]
# samplesetname

# %%
wm.upload_samples(newsample)
wm.update_sample_set(samplesetname,newsample.index)
# Out:
# Successfully imported 18 participants.
# Successfully imported 38 samples.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-bb0997f90425> in <module>()
# ----> 1 wm.upload_samples(newsample)
#       2 wm.update_sample_set(setname,newsample.index)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/dalmatian/base.py in upload_samples(self, df, participant_df, add_participant_samples)
#     238         sample_df = df[df.columns[df.columns!='sample_set_id']].copy()
#     239         sample_df.index.name = 'entity:sample_id'
# --> 240         self.upload_entities('sample', sample_df)
#     241
#     242         # 3) upload sample sets
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/dalmatian/wmanager.py in call_with_lock(self, *args, **kwargs)
#     149     def call_with_lock(self, *args, **kwargs):
#     150         with self.lock:
# --> 151             return func(self, *args, **kwargs)
#     152     return call_with_lock
#     153
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/dalmatian/wmanager.py in upload_entities(self, etype, df, index)
#     895         if self.live:
#     896             try:
# --> 897                 super().upload_entities(etype, df, index)
#     898                 self.cache[key] = getter()
#     899                 if key in self.dirty:
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/dalmatian/base.py in upload_entities(self, etype, df, index)
#     188                                     eid,
#     189                                     attr,
# --> 190                                     val
#     191                                 )
#     192         else:
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/hound/client.py in call_with_reason(self, *args, **kwargs)
#      99             if self.get_current_reason() is not None:
#     100                 arguments['reason'] = self.context_reason.reason
# --> 101         return func(**arguments)
#     102
#     103     return call_with_reason
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/hound/client.py in update_entity_attribute(self, etype, entity, attribute, value, reason)
#     237                 'attributeName': attribute,
#     238                 'attributeValue': value,
# --> 239                 'updateReason': reason if reason is not None else "No reason given"
#     240             }
#     241         )
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/hound/client.py in write(self, path, data)
#     214         else:
#     215             blob = storage.Blob(path, self.bucket)
# --> 216             blob.upload_from_string(json.dumps(data))
#     217         return path
#     218
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/google/cloud/storage/blob.py in upload_from_string(self, data, content_type, client, predefined_acl)
#    1255             content_type=content_type,
#    1256             client=client,
# -> 1257             predefined_acl=predefined_acl,
#    1258         )
#    1259
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/google/cloud/storage/blob.py in upload_from_file(self, file_obj, rewind, size, content_type, num_retries, client, predefined_acl)
#    1155         try:
#    1156             created_json = self._do_upload(
# -> 1157                 client, file_obj, content_type, size, num_retries, predefined_acl
#    1158             )
#    1159             self._set_properties(created_json)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/google/cloud/storage/blob.py in _do_upload(self, client, stream, content_type, size, num_retries, predefined_acl)
#    1061         if size is not None and size <= _MAX_MULTIPART_SIZE:
#    1062             response = self._do_multipart_upload(
# -> 1063                 client, stream, content_type, size, num_retries, predefined_acl
#    1064             )
#    1065         else:
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/google/cloud/storage/blob.py in _do_multipart_upload(self, client, stream, content_type, size, num_retries, predefined_acl)
#     855             )
#     856
# --> 857         response = upload.transmit(transport, data, object_metadata, content_type)
#     858
#     859         return response
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/google/resumable_media/requests/upload.py in transmit(self, transport, data, metadata, content_type)
#      95         result = _helpers.http_request(
#      96             transport, method, url, data=payload, headers=headers,
# ---> 97             retry_strategy=self._retry_strategy)
#      98         self._process_response(result)
#      99         return result
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/google/resumable_media/requests/_helpers.py in http_request(transport, method, url, data, headers, retry_strategy, **transport_kwargs)
#      99         **transport_kwargs)
#     100     return _helpers.wait_and_retry(
# --> 101         func, RequestsMixin._get_status_code, retry_strategy)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/google/resumable_media/_helpers.py in wait_and_retry(func, get_status_code, retry_strategy)
#     144         object: The return value of ``func``.
#     145     """
# --> 146     response = func()
#     147     if get_status_code(response) not in RETRYABLE:
#     148         return response
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/google/auth/transport/requests.py in request(self, method, url, data, headers, **kwargs)
#     206
#     207         response = super(AuthorizedSession, self).request(
# --> 208             method, url, data=data, headers=request_headers, **kwargs)
#     209
#     210         # If the response indicated that the credentials needed to be
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda2/envs/py36/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/anaconda2/envs/py36/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/anaconda2/envs/py36/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/anaconda2/envs/py36/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %% [markdown]
# ## creating the sample set for normal cells with m/f

# %%
normalsXX = newsample[(newsample["sample_type"]=="Germline") & (newsample["sj_datasets"]!="Clinical Pilot") &(newsample["attr_sex"]=="Female")].index.values
normalsXY = newsample[(newsample["sample_type"]=="Germline") & (newsample["sj_datasets"]!="Clinical Pilot") &(newsample["attr_sex"]=="Male")].index.values

# %%
normalsXX
# Out:
# array(['SJRHB002_G', 'SJRHB005_G', 'SJRHB009_G', 'SJRHB013_G',
#        'SJRHB003_G', 'SJRHB008_G', 'SJRHB006_G', 'SJRHB030264_G1',
#        'SJRHB030115_G1'], dtype=object)

# %%
wm.update_sample_set(samplesetname+"_normals_XY",normalsXY.tolist())
# Out:
# Successfully imported 1 sample sets:
#   * WGS_CNV_stjude_normals_XY (6 samples)

# %%
wm.update_sample_set(samplesetname+"_normals_XX1",normalsXX.tolist())
# Out:
# Successfully imported 1 sample sets:
#   * WGS_CNV_stjude_normals_XX1 (9 samples)

# %% [markdown]
# ## creating the sample set for cancer patients with/without germline cells sequenced
#
# I am quite positive that the clinical pilot are not germline and have been misclassified

# %%
# diagnosis samples
diagnosis = newsample[(newsample["sample_type"]!="Germline") | (newsample["sj_datasets"]=="Clinical Pilot")]['participant_id'].values.tolist()
# germline samples
germline = newsample[(newsample["sample_type"]=="Germline") & (newsample["sj_datasets"]!="Clinical Pilot")]['participant_id'].values.tolist()
# assert that we have them all in total
assert(len(diagnosis)+len(germline)==newsample.shape[0]) 
# people without a matching germline
patientswithout = set(diagnosis) - set(germline)
# samples from patients without a matching germline
toprocessPON = newsample[newsample["participant_id"].isin(patientswithout)].index.values.tolist()
# samples from patients with a matching germline
not_toprocessPON = newsample[~newsample["participant_id"].isin(patientswithout)][newsample["sample_type"]=="Germline"].index.values.tolist()
# Out:
# /Users/jeremie/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':

# %%
wm.update_sample_set(samplesetname+"_not_toprocessPON",not_toprocessPON)
wm.update_sample_set(samplesetname+"_toprocessPON",toprocessPON)

# %%
cnv_pon = wm.get_config("CNV_Somatic_Panel_Workflow")
cnv_pon
# Out:
# {'deleted': False,
#  'inputs': {'CNVSomaticPanelWorkflow.normal_bams': 'this.samples.WGS_bam',
#   'CNVSomaticPanelWorkflow.preemptible_attempts': '5',
#   'CNVSomaticPanelWorkflow.normal_bais': 'this.samples.WGS_bam_index',
#   'CNVSomaticPanelWorkflow.bin_length': '1000',
#   'CNVSomaticPanelWorkflow.ref_fasta_dict': 'workspace.ref_dict',
#   'CNVSomaticPanelWorkflow.gatk4_jar_override': '',
#   'CNVSomaticPanelWorkflow.mem_gb_for_preprocess_intervals': '16',
#   'CNVSomaticPanelWorkflow.PreprocessIntervals.cpu': '8',
#   'CNVSomaticPanelWorkflow.pon_entity_id': 'this.name',
#   'CNVSomaticPanelWorkflow.CollectCounts.cpu': '8',
#   'CNVSomaticPanelWorkflow.CollectCounts.disk_space_gb': '500',
#   'CNVSomaticPanelWorkflow.ref_fasta_fai': 'workspace.ref_fasta_fai',
#   'CNVSomaticPanelWorkflow.AnnotateIntervals.cpu': '8',
#   'CNVSomaticPanelWorkflow.mem_gb_for_annotate_intervals': '16',
#   'CNVSomaticPanelWorkflow.gatk_docker': 'workspace.gatk_docker',
#   'CNVSomaticPanelWorkflow.ref_fasta': 'workspace.ref_fasta',
#   'CNVSomaticPanelWorkflow.CreateReadCountPanelOfNormals.disk_space_gb': '500',
#   'CNVSomaticPanelWorkflow.do_explicit_gc_correction': '"True"',
#   'CNVSomaticPanelWorkflow.CreateReadCountPanelOfNormals.cpu': '8',
#   'CNVSomaticPanelWorkflow.minimum_interval_median_percentile': '10.0',
#   'CNVSomaticPanelWorkflow.mem_gb_for_create_read_count_pon': '16',
#   'CNVSomaticPanelWorkflow.PreprocessIntervals.disk_space_gb': '500',
#   'CNVSomaticPanelWorkflow.padding': '250',
#   'CNVSomaticPanelWorkflow.number_of_eigensamples': '',
#   'CNVSomaticPanelWorkflow.intervals': '"gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642da12f8/immediate/intervalsXY.list"',
#   'CNVSomaticPanelWorkflow.AnnotateIntervals.disk_space_gb': '500'},
#  'methodConfigVersion': 106,
#  'methodRepoMethod': {'methodName': 'CNV_Somatic_Panel_Workflow',
#   'methodVersion': 13,
#   'methodNamespace': 'gatk',
#   'methodUri': 'agora://gatk/CNV_Somatic_Panel_Workflow/13',
#   'sourceRepo': 'agora'},
#  'name': 'CNV_Somatic_Panel_Workflow',
#  'namespace': 'gatk',
#  'outputs': {'CNVSomaticPanelWorkflow.preprocessed_intervals': 'this.preprocessed_intervals',
#   'CNVSomaticPanelWorkflow.read_counts': 'this.read_counts',
#   'CNVSomaticPanelWorkflow.read_counts_entity_ids': 'this.read_counts_entity_ids',
#   'CNVSomaticPanelWorkflow.read_count_pon': 'this.read_count_pon'},
#  'prerequisites': {},
#  'rootEntityType': 'sample_set'}

# %%
cnv_pon['inputs']['CNVSomaticPanelWorkflow.normal_bams'] = 'this.samples.WGS_bam'
cnv_pon['inputs']['CNVSomaticPanelWorkflow.normal_bais'] = 'this.samples.WGS_bam_index'

## runing male PON
#a['inputs']['CNVSomaticPanelWorkflow.intervals'] = '"'+maleintervals+'"'


#wm.create_submission(a, setname+"_normals_XY", 'sample_set', use_callcache=True)

## running female PON
cnv_pon['inputs']['CNVSomaticPanelWorkflow.intervals'] = '"'+femaleintervals+'"'
wm.update_config(cnv_pon)
wm.create_submission(cnv_pon['name'], samplesetname+"_normals_XX1", 'sample_set', use_callcache=True)
# Out:
# User provided a full method configuration, which did not match the configuration already present on the workspace
# Either upload the provided configuration, or use a different reference type to fetch the online version
# ---------------------------------------------------------------------------
# ConfigNotUnique                           Traceback (most recent call last)
# <ipython-input-31-9d959d1196c0> in <module>()
#      10 ## running female PON
#      11 a['inputs']['CNVSomaticPanelWorkflow.intervals'] = '"'+femaleintervals+'"'
# ---> 12 wm.create_submission(a, setname+"_normals_XX1", 'sample_set', use_callcache=True)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/dalmatian/wmanager.py in create_submission(self, config, entity, etype, expression, use_callcache)
#    1430                     print("User provided a full method configuration, which did not match the configuration already present on the workspace", file=sys.stderr)
#    1431                     print("Either upload the provided configuration, or use a different reference type to fetch the online version", file=sys.stderr)
# -> 1432                     raise ConfigNotUnique("Provided configuration did not match live version {}/{}".format(cfg['namespace'], cfg['name']))
#    1433             except ConfigNotFound:
#    1434                 self.update_config(config)
#
# ConfigNotUnique: 'Provided configuration did not match live version gatk/CNV_Somatic_Panel_Workflow'

# %% [markdown]
# ## running specific PON

# %%
pairs = newsample[~newsample["participant_id"].isin(patientswithout)][newsample["sample_type"]!="Germline"].index.values.tolist()
nomatched = newsample[newsample["participant_id"].isin(patientswithout)].index.values.tolist()
# Out:
# /Users/jeremie/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
sampleset = wm.get_sample_sets()
samples = wm.get_samples()
new_dataset = pd.DataFrame(columns=[samplesetname+"_id","read_count_pon","WGS_bam_tumor","WGS_bam_normal","WGS_bam_normal_index","WGS_bam_tumor_index","intervals"])

# %%
samples=samples.drop(labels="SJRHB007_G")
samples=samples.drop(labels="SJRHB010_D")

# %%
for val in nomatched:
    sex = "_normals_XY" if newsample["attr_sex"][val]!="Female" else "_normals_XX1" 
    intervals = maleintervals if samples["attr_sex"][val]!="Female" else femaleintervals 
    new_dataset = new_dataset.append({
        samplesetname+"_id": val,
        "read_count_pon": sampleset["read_count_pon"][samplesetname+sex],
        "WGS_bam_tumor": samples["WGS_bam"][val],
        "WGS_bam_normal": "",
        "WGS_bam_normal_index": "",
        "WGS_bam_tumor_index": samples["WGS_bam_index"][val],
        "intervals": intervals
    },ignore_index=True)

# %%
for val in pairs:
    paired_germline = samples[samples["participant"]==samples["participant"][val]][samples["sample_type"]=="Germline"]
    sex = "_normals_XY" if samples["attr_sex"][val]!="Female" else "_normals_XX" 
    read_count_pon = sampleset["read_count_pon"][samplesetname+sex]
    intervals = maleintervals if samples["attr_sex"][val]!="Female" else femaleintervals 
    new_dataset = new_dataset.append({
        samplesetname+"_id": val,
        "read_count_pon": read_count_pon,
        "WGS_bam_tumor": samples["WGS_bam"][val],
        "WGS_bam_normal": paired_germline["WGS_bam"].values[0],
        "WGS_bam_normal_index": paired_germline["WGS_bam_index"].values[0],
        "WGS_bam_tumor_index": samples["WGS_bam_index"][val],
        "intervals": intervals
    },ignore_index=True)
# Out:
# /Users/jeremie/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
new_dataset.set_index(samplesetname+"_id",inplace=True,drop=True)

# %%
wm.upload_entities(samplesetname,new_dataset)
# Out:
# Traceback (most recent call last):
#   File "/Users/jeremie/anaconda2/envs/py36/lib/python3.6/site-packages/dalmatian/wmanager.py", line 897, in upload_entities
#     super().upload_entities(etype, df, index)
#   File "/Users/jeremie/anaconda2/envs/py36/lib/python3.6/site-packages/dalmatian/base.py", line 193, in upload_entities
#     raise APIException('{} import failed.'.format(et.capitalize()), s)
# dalmatian.core.APIException: Pairs_cnv1 import failed.: (400) : {
#   "statusCode": 400,
#   "source": "FireCloud",
#   "timestamp": 1559323885740,
#   "causes": [],
#   "stackTrace": [],
#   "message": "ErrorReport(FireCloud,Unknown firecloud model entity type: pair_CNV1,Some(400 Bad Request),List(),List(),None)"
# }
#
# WARNING: The operation cache is now offline for rmc-rnaseq/St_Jude_RMS

# %%
new_dataset.to_csv("hello.tsv", sep='\t')

# %%
CNVpipeline = wm.get_config('CNV_Somatic_Pair_Workflow')
CNVpipeline
# Out:
# {'deleted': False,
#  'inputs': {'CNVSomaticPairWorkflow.ModelSegmentsNormal.output_dir': '',
#   'CNVSomaticPairWorkflow.PlotModeledSegmentsTumor.output_dir': '',
#   'CNVSomaticPairWorkflow.ModelSegmentsTumor.output_dir': '',
#   'CNVSomaticPairWorkflow.gatk_docker': 'workspace.gatk_docker',
#   'CNVSomaticPairWorkflow.common_sites': 'workspace.common_sites_hg38',
#   'CNVSomaticPairWorkflow.tumor_bam_idx': 'this.WGS_bam_tumor_index',
#   'CNVSomaticPairWorkflow.emergency_extra_disk': '',
#   'CNVSomaticPairWorkflow.ModelSegmentsNormal.normal_allelic_counts': '',
#   'CNVSomaticPairWorkflow.PlotModeledSegmentsNormal.output_dir': '',
#   'CNVSomaticPairWorkflow.ref_fasta_fai': 'workspace.ref_fasta_fai',
#   'CNVSomaticPairWorkflow.ref_fasta': 'workspace.ref_fasta',
#   'CNVSomaticPairWorkflow.ref_fasta_dict': 'workspace.ref_dict',
#   'CNVSomaticPairWorkflow.PlotDenoisedCopyRatiosNormal.output_dir': '',
#   'CNVSomaticPairWorkflow.tumor_bam': 'this.WGS_bam_tumor',
#   'CNVSomaticPairWorkflow.normal_bam_idx': 'this.WGS_bam_normal_index',
#   'CNVSomaticPairWorkflow.PlotDenoisedCopyRatiosTumor.output_dir': '',
#   'CNVSomaticPairWorkflow.is_run_oncotator': '"True"',
#   'CNVSomaticPairWorkflow.padding': 250,
#   'CNVSomaticPairWorkflow.normal_bam': 'this.WGS_bam_normal',
#   'CNVSomaticPairWorkflow.intervals': 'workspace.interval_list',
#   'CNVSomaticPairWorkflow.gatk4_jar_override': '',
#   'CNVSomaticPairWorkflow.read_count_pon': 'this.read_count_pon',
#   'CNVSomaticPairWorkflow.bin_length': 1000},
#  'methodConfigVersion': 10,
#  'methodRepoMethod': {'methodName': 'CNV_Somatic_Pair_Workflow',
#   'methodVersion': 12,
#   'methodNamespace': 'gatk',
#   'methodUri': 'agora://gatk/CNV_Somatic_Pair_Workflow/12',
#   'sourceRepo': 'agora'},
#  'name': 'CNV_Somatic_Pair_Workflow',
#  'namespace': 'gatk',
#  'outputs': {'CNVSomaticPairWorkflow.copy_ratio_legacy_segments_normal': 'this.copy_ratio_legacy_segments_normal',
#   'CNVSomaticPairWorkflow.het_allelic_counts_normal': 'this.het_allelic_counts_normal',
#   'CNVSomaticPairWorkflow.allelic_counts_normal': 'this.allelic_counts_normal',
#   'CNVSomaticPairWorkflow.copy_ratio_parameters_normal': 'this.copy_ratio_parameters_normal',
#   'CNVSomaticPairWorkflow.allele_fraction_legacy_segments_normal': 'this.allele_fraction_legacy_segments_normal',
#   'CNVSomaticPairWorkflow.normal_het_allelic_counts_normal': 'this.normal_het_allelic_counts_normal',
#   'CNVSomaticPairWorkflow.allele_fraction_parameters_normal': 'this.allele_fraction_parameters_normal',
#   'CNVSomaticPairWorkflow.modeled_segments_begin_tumor': 'this.modeled_segments_begin_tumor',
#   'CNVSomaticPairWorkflow.copy_ratio_parameters_begin_normal': 'this.copy_ratio_parameters_begin_normal',
#   'CNVSomaticPairWorkflow.copy_ratio_parameters_tumor': 'this.copy_ratio_parameters_tumor',
#   'CNVSomaticPairWorkflow.denoised_MAD_normal': 'this.denoised_MAD_normal',
#   'CNVSomaticPairWorkflow.scaled_delta_MAD_tumor': 'this.scaled_delta_MAD_tumor',
#   'CNVSomaticPairWorkflow.het_allelic_counts_tumor': 'this.het_allelic_counts_tumor',
#   'CNVSomaticPairWorkflow.scaled_delta_MAD_normal': 'this.scaled_delta_MAD_normal',
#   'CNVSomaticPairWorkflow.standardized_MAD_tumor': 'this.standardized_MAD_tumor',
#   'CNVSomaticPairWorkflow.denoised_copy_ratios_plot_tumor': 'this.denoised_copy_ratios_plot_tumor',
#   'CNVSomaticPairWorkflow.copy_ratio_only_segments_tumor': 'this.copy_ratio_only_segments_tumor',
#   'CNVSomaticPairWorkflow.oncotated_called_gene_list_file_tumor': 'this.oncotated_called_gene_list_file_tumor',
#   'CNVSomaticPairWorkflow.denoised_copy_ratios_normal': 'this.denoised_copy_ratios_normal',
#   'CNVSomaticPairWorkflow.called_copy_ratio_segments_normal': 'this.called_copy_ratio_segments_normal',
#   'CNVSomaticPairWorkflow.denoised_copy_ratios_lim_4_plot_normal': 'this.denoised_copy_ratios_lim_4_plot_normal',
#   'CNVSomaticPairWorkflow.oncotated_called_file_tumor': 'this.oncotated_called_file_tumor',
#   'CNVSomaticPairWorkflow.allele_fraction_parameters_begin_normal': 'this.allele_fraction_parameters_begin_normal',
#   'CNVSomaticPairWorkflow.delta_MAD_normal': 'this.delta_MAD_normal',
#   'CNVSomaticPairWorkflow.denoised_MAD_tumor': 'this.denoised_MAD_tumor',
#   'CNVSomaticPairWorkflow.normal_het_allelic_counts_tumor': 'this.normal_het_allelic_counts_tumor',
#   'CNVSomaticPairWorkflow.copy_ratio_only_segments_normal': 'this.copy_ratio_only_segments_normal',
#   'CNVSomaticPairWorkflow.modeled_segments_begin_normal': 'this.modeled_segments_begin_normal',
#   'CNVSomaticPairWorkflow.denoised_copy_ratios_tumor': 'this.denoised_copy_ratios_tumor',
#   'CNVSomaticPairWorkflow.denoised_copy_ratios_lim_4_plot_tumor': 'this.denoised_copy_ratios_lim_4_plot_tumor',
#   'CNVSomaticPairWorkflow.allelic_counts_entity_id_normal': 'this.allelic_counts_entity_id_normal',
#   'CNVSomaticPairWorkflow.modeled_segments_tumor': 'this.modeled_segments_tumor',
#   'CNVSomaticPairWorkflow.allele_fraction_parameters_begin_tumor': 'this.allele_fraction_parameters_begin_tumor',
#   'CNVSomaticPairWorkflow.allelic_counts_tumor': 'this.allelic_counts_tumor',
#   'CNVSomaticPairWorkflow.read_counts_entity_id_tumor': 'this.read_counts_entity_id_tumor',
#   'CNVSomaticPairWorkflow.standardized_MAD_normal': 'this.standardized_MAD_normal',
#   'CNVSomaticPairWorkflow.delta_MAD_tumor': 'this.delta_MAD_tumor',
#   'CNVSomaticPairWorkflow.read_counts_normal': 'this.read_counts_normal',
#   'CNVSomaticPairWorkflow.read_counts_tumor': 'this.read_counts_tumor',
#   'CNVSomaticPairWorkflow.modeled_segments_plot_normal': 'this.modeled_segments_plot_normal',
#   'CNVSomaticPairWorkflow.modeled_segments_plot_tumor': 'this.modeled_segments_plot_tumor',
#   'CNVSomaticPairWorkflow.denoised_copy_ratios_plot_normal': 'this.denoised_copy_ratios_plot_normal',
#   'CNVSomaticPairWorkflow.modeled_segments_normal': 'this.modeled_segments_normal',
#   'CNVSomaticPairWorkflow.allele_fraction_legacy_segments_tumor': 'this.allele_fraction_legacy_segments_tumor',
#   'CNVSomaticPairWorkflow.allelic_counts_entity_id_tumor': 'this.allelic_counts_entity_id_tumor',
#   'CNVSomaticPairWorkflow.copy_ratio_legacy_segments_tumor': 'this.copy_ratio_legacy_segments_tumor',
#   'CNVSomaticPairWorkflow.standardized_copy_ratios_normal': 'this.standardized_copy_ratios_normal',
#   'CNVSomaticPairWorkflow.called_copy_ratio_segments_tumor': 'this.called_copy_ratio_segments_tumor',
#   'CNVSomaticPairWorkflow.read_counts_entity_id_normal': 'this.read_counts_entity_id_normal',
#   'CNVSomaticPairWorkflow.preprocessed_intervals': 'this.preprocessed_intervals',
#   'CNVSomaticPairWorkflow.standardized_copy_ratios_tumor': 'this.standardized_copy_ratios_tumor',
#   'CNVSomaticPairWorkflow.allele_fraction_parameters_tumor': 'this.allele_fraction_parameters_tumor',
#   'CNVSomaticPairWorkflow.copy_ratio_parameters_begin_tumor': 'this.copy_ratio_parameters_begin_tumor'},
#  'prerequisites': {},
#  'rootEntityType': 'pair'}

# %%
CNVpipeline['inputs']['CNVSomaticPairWorkflow.tumor_bam'] = 'this.WGS_bam_tumor'
CNVpipeline['inputs']['CNVSomaticPairWorkflow.tumor_bam_idx'] = 'this.WGS_bam_tumor_index'
CNVpipeline['inputs']['CNVSomaticPairWorkflow.normal_bam'] = 'this.WGS_bam_normal'
CNVpipeline['inputs']['CNVSomaticPairWorkflow.normal_bam_idx'] = 'this.WGS_bam_normal_index'
CNVpipeline['inputs']['CNVSomaticPairWorkflow.padding'] = 250
CNVpipeline['rootEntityType']= 'pair'
CNVpipeline['inputs']['CNVSomaticPairWorkflow.common_sites'] = 'workspace.common_sites_hg38'
## runing male PON
CNVpipeline['inputs']['CNVSomaticPairWorkflow.intervals'] = 'workspace.interval_list'
CNVpipeline['inputs']['CNVSomaticPairWorkflow.read_count_pon'] = 'this.read_count_pon'
CNVpipeline['inputs']['CNVSomaticPairWorkflow.bin_length'] = 1000
wm.update_config(CNVpipeline)
submission_id = wm.create_submission(CNVpipeline['name'],etype='sample_set',entity=samplesetname,expression='this.samples')
failed_submission = []
terra.wait_for_submission(submission_id)

# %%
aggregate = wm.get_config('Aggregate_CN_seg_files')
aggregate
# Out:
# {'deleted': False,
#  'inputs': {'aggregate_CN_segments_wrkflw.aggregate_CN_segments.disk_space': '10',
#   'aggregate_CN_segments_wrkflw.aggregate_CN_segments.num_preempt': '5',
#   'aggregate_CN_segments_wrkflw.aggregate_CN_segments.aggregate_seg_files_script': '"gs://fc-secure-fbcce9b4-7b36-443f-974f-7165ece39714/references/generate_single_seg_file.R"',
#   'aggregate_CN_segments_wrkflw.aggregate_CN_segments.memory': '5',
#   'aggregate_CN_segments_wrkflw.aggregate_CN_segments.sample_set_id': 'this.name',
#   'aggregate_CN_segments_wrkflw.aggregate_CN_segments.sample_seg_files': 'this.samples.called_copy_ratio_segments_tumor'},
#  'methodConfigVersion': 2,
#  'methodRepoMethod': {'methodName': 'Aggregate_CN_seg_files',
#   'methodVersion': 2,
#   'methodNamespace': 'gkugener',
#   'methodUri': 'agora://gkugener/Aggregate_CN_seg_files/2',
#   'sourceRepo': 'agora'},
#  'name': 'Aggregate_CN_seg_files',
#  'namespace': 'gkugener',
#  'outputs': {'aggregate_CN_segments_wrkflw.aggregate_CN_segments.combined_cn_file': 'this.combined_seg_file'},
#  'prerequisites': {},
#  'rootEntityType': 'sample_set'}

# %%
aggregate['inputs']['aggregate_CN_segments_wrkflw.aggregate_CN_segments.sample_seg_files'] = 'this.samples.called_copy_ratio_segments_tumor'
wm.update_config(aggregate)
submission_id = wm.create_submission(config = aggregate['name'], etype='sample_set', entity=samplesetname, expression='this.samples')
terra.wait_for_submission(submission_id)
# Out:
# Successfully updated configuration gkugener/Aggregate_CN_seg_files
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-cd38861683d8> in <module>()
#       1 wm.update_config(aggregate)
# ----> 2 submission_id1 = wm.create_submission(config = aggregate['name'], etype='sample_set', entity='pair_CNV1', expression='this.samples')
#       3
#       4 submission_id2 = wm.create_submission(config = aggregate['name'], etype='sample_set', entity='pair_CNV', expression='this.samples')
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/dalmatian/wmanager.py in create_submission(self, config, entity, etype, expression, use_callcache)
#    1435         preflight = self.preflight(config, entity, expression, etype)
#    1436         if not preflight.result:
# -> 1437             raise ValueError(preflight.reason)
#    1438
#    1439         if len(preflight.invalid_inputs):
#
# ValueError: expression and etype must BOTH be None or a string value

# %%
aggregated = wm.get_entities(etype="pair_CNV_set")["combined_seg_file"].values[0]
aggregated
# Out:
# 'gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642da12f8/c3f21302-bf21-42cd-8907-0649a68bce4e/aggregate_CN_segments_wrkflw/0e3f0917-6250-4b03-89de-dea0da408f75/call-aggregate_CN_segments/Aggregate_CN_seg_files_2019-06-04T22-00-19.called.seg'

# %%
! gsutil cp $aggregated temp/
# Out:
# Copying gs://fc-secure-fd4c24cf-6bfd-410a-9bca-e02642da12f8/c3f21302-bf21-42cd-8907-0649a68bce4e/aggregate_CN_segments_wrkflw/0e3f0917-6250-4b03-89de-dea0da408f75/call-aggregate_CN_segments/Aggregate_CN_seg_files_2019-06-04T22-00-19.called.seg...
# / [1 files][576.7 KiB/576.7 KiB]
# Operation completed over 1 objects/576.7 KiB.

# %%
# %load_ext rpy2.ipython

# %% [markdown]
# you can even add `-i df -w 5 -h 5 --units in -r 200`

# %%
# %%R
# source("CCLE_postp_function.R")
# Out:
# 2019-06-05 06:06:58::WARNING  R[write to console]: Loading required package: AnnotationDbi
#
# 2019-06-05 06:06:58::WARNING  R[write to console]: Loading required package: stats4
#
# 2019-06-05 06:06:58::WARNING  R[write to console]: Loading required package: BiocGenerics
#
# 2019-06-05 06:06:58::WARNING  R[write to console]: Loading required package: parallel
#
# 2019-06-05 06:06:58::WARNING  R[write to console]:
# Attaching package: ‘BiocGenerics’
#
#
# 2019-06-05 06:06:58::WARNING  R[write to console]: The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# 2019-06-05 06:06:58::WARNING  R[write to console]: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# 2019-06-05 06:06:58::WARNING  R[write to console]: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colMeans,
#     colnames, colSums, dirname, do.call, duplicated, eval, evalq,
#     Filter, Find, get, grep, grepl, intersect, is.unsorted, lapply,
#     lengths, Map, mapply, match, mget, order, paste, pmax, pmax.int,
#     pmin, pmin.int, Position, rank, rbind, Reduce, rowMeans, rownames,
#     rowSums, sapply, setdiff, sort, table, tapply, union, unique,
#     unsplit, which, which.max, which.min
#
#
# 2019-06-05 06:06:58::WARNING  R[write to console]: Loading required package: Biobase
#
# 2019-06-05 06:06:58::WARNING  R[write to console]: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# 2019-06-05 06:06:58::WARNING  R[write to console]: Loading required package: IRanges
#
# 2019-06-05 06:06:58::WARNING  R[write to console]: Loading required package: S4Vectors
#
# 2019-06-05 06:06:59::WARNING  R[write to console]:
# Attaching package: ‘S4Vectors’
#
#
# 2019-06-05 06:06:59::WARNING  R[write to console]: The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# 2019-06-05 06:07:00::WARNING  R[write to console]:
#
# 2019-06-05 06:07:00::WARNING  R[write to console]:
# Attaching package: ‘plyr’
#
#
# 2019-06-05 06:07:00::WARNING  R[write to console]: The following object is masked from ‘package:IRanges’:
#
#     desc
#
#
# 2019-06-05 06:07:00::WARNING  R[write to console]: The following object is masked from ‘package:S4Vectors’:
#
#     rename
#
#
# 2019-06-05 06:07:01::WARNING  R[write to console]:
# Attaching package: ‘dplyr’
#
#
# 2019-06-05 06:07:01::WARNING  R[write to console]: The following objects are masked from ‘package:plyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# 2019-06-05 06:07:01::WARNING  R[write to console]: The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
#
# 2019-06-05 06:07:01::WARNING  R[write to console]: The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# 2019-06-05 06:07:01::WARNING  R[write to console]: The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# 2019-06-05 06:07:01::WARNING  R[write to console]: The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# 2019-06-05 06:07:01::WARNING  R[write to console]: The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# 2019-06-05 06:07:01::WARNING  R[write to console]: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# 2019-06-05 06:07:01::WARNING  R[write to console]: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: ✔ ggplot2 3.1.1     ✔ readr   1.3.1
# ✔ tibble  2.1.2     ✔ purrr   0.3.2
# ✔ tidyr   0.8.3     ✔ stringr 1.4.0
# ✔ ggplot2 3.1.1     ✔ forcats 0.4.0
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::arrange()    masks plyr::arrange()
# ✖ dplyr::collapse()   masks IRanges::collapse()
# ✖ dplyr::combine()    masks Biobase::combine(), BiocGenerics::combine()
# ✖ purrr::compact()    masks plyr::compact()
# ✖ dplyr::count()      masks plyr::count()
# ✖ dplyr::desc()       masks plyr::desc(), IRanges::desc()
# ✖ tidyr::expand()     masks S4Vectors::expand()
# ✖ dplyr::failwith()   masks plyr::failwith()
# ✖ dplyr::filter()     masks stats::filter()
# ✖ dplyr::first()      masks S4Vectors::first()
# ✖ dplyr::id()         masks plyr::id()
# ✖ dplyr::lag()        masks stats::lag()
# ✖ dplyr::mutate()     masks plyr::mutate()
# ✖ ggplot2::Position() masks BiocGenerics::Position(), base::Position()
# ✖ purrr::reduce()     masks IRanges::reduce()
# ✖ dplyr::rename()     masks plyr::rename(), S4Vectors::rename()
# ✖ dplyr::select()     masks AnnotationDbi::select()
# ✖ dplyr::slice()      masks IRanges::slice()
# ✖ dplyr::summarise()  masks plyr::summarise()
# ✖ dplyr::summarize()  masks plyr::summarize()
#
# 2019-06-05 06:07:02::WARNING  R[write to console]:
# Attaching package: ‘magrittr’
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:purrr’:
#
#     set_names
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:tidyr’:
#
#     extract
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]:
# Attaching package: ‘reshape2’
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:tidyr’:
#
#     smiths
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]:
# Attaching package: ‘gridExtra’
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:BiocGenerics’:
#
#     combine
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]:
# Attaching package: ‘ggridges’
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:ggplot2’:
#
#     scale_discrete_manual
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]:
# Attaching package: ‘GGally’
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:dplyr’:
#
#     nasa
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]:
# Attaching package: ‘plotly’
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following objects are masked from ‘package:plyr’:
#
#     arrange, mutate, rename, summarise
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:IRanges’:
#
#     slice
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:S4Vectors’:
#
#     rename
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:stats’:
#
#     filter
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:graphics’:
#
#     layout
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: Loading required package: grid
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: Loading required package: futile.logger
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: Registering fonts with R
#
# 2019-06-05 06:07:02::WARNING  R[write to console]:
# Attaching package: ‘cowplot’
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:ggthemes’:
#
#     theme_map
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:ggplot2’:
#
#     ggsave
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]:
# Attaching package: ‘data.table’
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following objects are masked from ‘package:reshape2’:
#
#     dcast, melt
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]:
# Attaching package: ‘DT’
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: The following object is masked from ‘package:networkD3’:
#
#     JS
#
#
# 2019-06-05 06:07:02::WARNING  R[write to console]: Loading required package: GenomeInfoDb
#
# 2019-06-05 06:07:03::WARNING  R[write to console]: Loading required package: annotate
#
# 2019-06-05 06:07:03::WARNING  R[write to console]: Loading required package: XML
#
# 2019-06-05 06:07:03::WARNING  R[write to console]:
# Attaching package: ‘XML’
#
#
# 2019-06-05 06:07:03::WARNING  R[write to console]: The following object is masked from ‘package:tools’:
#
#     toHTML
#
#
# 2019-06-05 06:07:04::WARNING  R[write to console]: Loading required package: graph
#
# 2019-06-05 06:07:04::WARNING  R[write to console]:
# Attaching package: ‘graph’
#
#
# 2019-06-05 06:07:04::WARNING  R[write to console]: The following object is masked from ‘package:XML’:
#
#     addNode
#
#
# 2019-06-05 06:07:04::WARNING  R[write to console]: The following object is masked from ‘package:stringr’:
#
#     boundary
#
#
# 2019-06-05 06:07:04::WARNING  R[write to console]: The following object is masked from ‘package:plyr’:
#
#     join
#
#
# 2019-06-05 06:07:04::WARNING  R[write to console]: Loading required package: RCurl
#
# 2019-06-05 06:07:04::WARNING  R[write to console]: Loading required package: bitops
#
# 2019-06-05 06:07:04::WARNING  R[write to console]:
# Attaching package: ‘RCurl’
#
#
# 2019-06-05 06:07:04::WARNING  R[write to console]: The following object is masked from ‘package:tidyr’:
#
#     complete
#
#
# 2019-06-05 06:07:04::WARNING  R[write to console]: Loading required package: httr
#
# 2019-06-05 06:07:04::WARNING  R[write to console]:
# Attaching package: ‘httr’
#
#
# 2019-06-05 06:07:04::WARNING  R[write to console]: The following object is masked from ‘package:plotly’:
#
#     config
#
#
# 2019-06-05 06:07:04::WARNING  R[write to console]: The following object is masked from ‘package:Biobase’:
#
#     content
#
#
# 2019-06-05 06:07:04::WARNING  R[write to console]: Package 'mclust' version 5.4.3
# Type 'citation("mclust")' for citing this R package in publications.
#
# 2019-06-05 06:07:04::WARNING  R[write to console]:
# Attaching package: ‘mclust’
#
#
# 2019-06-05 06:07:04::WARNING  R[write to console]: The following object is masked from ‘package:purrr’:
#
#     map
#
#
# 2019-06-05 06:07:05::WARNING  R[write to console]: Loading required package: mgcv
#
# 2019-06-05 06:07:05::WARNING  R[write to console]: Loading required package: nlme
#
# 2019-06-05 06:07:05::WARNING  R[write to console]:
# Attaching package: ‘nlme’
#
#
# 2019-06-05 06:07:05::WARNING  R[write to console]: The following object is masked from ‘package:dplyr’:
#
#     collapse
#
#
# 2019-06-05 06:07:05::WARNING  R[write to console]: The following object is masked from ‘package:IRanges’:
#
#     collapse
#
#
# 2019-06-05 06:07:05::WARNING  R[write to console]: This is mgcv 1.8-28. For overview type 'help("mgcv-package")'.
#
# 2019-06-05 06:07:05::WARNING  R[write to console]:
# Attaching package: ‘mgcv’
#
#
# 2019-06-05 06:07:05::WARNING  R[write to console]: The following object is masked from ‘package:mclust’:
#
#     mvn
#
#
# 2019-06-05 06:07:05::WARNING  R[write to console]: The following object is masked from ‘package:futile.logger’:
#
#     scat
#
#
# 2019-06-05 06:07:06::WARNING  R[write to console]: Loading required package: genefilter
#
# 2019-06-05 06:07:06::WARNING  R[write to console]:
# Attaching package: ‘genefilter’
#
#
# 2019-06-05 06:07:06::WARNING  R[write to console]: The following object is masked from ‘package:readr’:
#
#     spec
#
#
# 2019-06-05 06:07:06::WARNING  R[write to console]: Loading required package: BiocParallel
#
# 2019-06-05 06:07:06::WARNING  R[write to console]:
# Attaching package: ‘limma’
#
#
# 2019-06-05 06:07:06::WARNING  R[write to console]: The following object is masked from ‘package:BiocGenerics’:
#
#     plotMA
#
#
# 2019-06-05 06:07:06::WARNING  R[write to console]: Loading required package: lpSolve
#
# 2019-06-05 06:07:06::WARNING  R[write to console]:
# Attaching package: ‘zoo’
#
#
# 2019-06-05 06:07:06::WARNING  R[write to console]: The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# 2019-06-05 06:07:06::WARNING  R[write to console]:
# Attaching package: ‘scales’
#
#
# 2019-06-05 06:07:06::WARNING  R[write to console]: The following object is masked from ‘package:purrr’:
#
#     discard
#
#
# 2019-06-05 06:07:06::WARNING  R[write to console]: The following object is masked from ‘package:readr’:
#
#     col_factor
#
#
# 2019-06-05 06:07:06::WARNING  R[write to console]:
# Attaching package: ‘rlang’
#
#
# 2019-06-05 06:07:06::WARNING  R[write to console]: The following object is masked from ‘package:data.table’:
#
#     :=
#
#
# 2019-06-05 06:07:06::WARNING  R[write to console]: The following object is masked from ‘package:magrittr’:
#
#     set_names
#
#
# 2019-06-05 06:07:07::WARNING  R[write to console]: The following objects are masked from ‘package:purrr’:
#
#     %@%, as_function, flatten, flatten_chr, flatten_dbl, flatten_int,
#     flatten_lgl, flatten_raw, invoke, list_along, modify, prepend,
#     splice
#
#
# 2019-06-05 06:07:07::WARNING  R[write to console]: The following object is masked from ‘package:Biobase’:
#
#     exprs
#
#
# 2019-06-05 06:07:07::WARNING  R[write to console]: Loading required package: SnowballC
# Fetching https://cds.team/taiga/api/dataset/msigdb-gene-set-collections-8453/2
# Status 200
# 2019-06-05 06:07:07::WARNING  R[write to console]: No encoding supplied: defaulting to UTF-8.
# loading cached data version from  ~/.taiga/msigdb-gene-set-collections-8453_2.toc
# Checking for cached file ~/.taiga/495ea37b8d744a428946a5628c5fe7ce_gsc-data.raw

# %%
# %%R
# a <- interpolate_gaps_in_segmented(process_segments(
#     "temp/Aggregate_CN_seg_files_2019-06-04T22-00-19.called.seg"))
# segments <- extend_ends_of_segments(a$segs)
# Out:
# [1] 0
# 2019-06-05 06:08:03::WARNING  R[write to console]: Parsed with column specification:
# cols(
#   X1 = col_character(),
#   X2 = col_double(),
#   X3 = col_double(),
#   X4 = col_character(),
#   X5 = col_character()
# )

# %%
# %%R
# write.table(segments, file = "output_StJude.csv", sep = ',', quote = F, row.names = F)
# # What we upload to taiga
# Out:
# Parsed with column specification:
# cols(
#   X1 = col_character(),
#   X2 = col_double(),
#   X3 = col_double(),
#   X4 = col_character(),
#   X5 = col_character()
# )
